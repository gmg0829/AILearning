# %% [markdown]
# # 目录

# %%
import pandas as pd
import numpy as np
import featuretools as ft

# %% [markdown]
# ## 加载数据

# %%
# %%time
clients = pd.read_csv('./clients.csv', parse_dates = ['joined'])
loans = pd.read_csv('./loans.csv', parse_dates = ['loan_start', 'loan_end'])
payments = pd.read_csv('./payments.csv', parse_dates = ['payment_date'])
# Out:
# Wall time: 1.1 s

# %%
# %%time
clients.head()
# Out:
# Wall time: 17 ms
#    client_id     joined  income  credit_score
# 0      46109 2002-04-16  172677           527
# 1      49545 2007-11-14  104564           770
# 2      41480 2013-03-11  122607           585
# 3      46180 2001-11-06   43851           562
# 4      25707 2006-10-06  211422           621

# %%
loans.head()
# Out:
#    client_id loan_type  loan_amount  repaid  loan_id loan_start   loan_end  \
# 0      46109      home        13672       0    10243 2002-04-16 2003-12-20
# 1      46109    credit         9794       0    10984 2003-10-21 2005-07-17
# 2      46109      home        12734       1    10990 2006-02-01 2007-07-05
# 3      46109      cash        12518       1    10596 2010-12-08 2013-05-05
# 4      46109    credit        14049       1    11415 2010-07-07 2012-05-21
#
#    rate
# 0  2.15
# 1  1.25
# 2  0.68
# 3  1.24
# 4  3.13

# %%
payments.head()
# Out:
#    loan_id  payment_amount payment_date  missed
# 0    10243            2369   2002-05-31       1
# 1    10243            2439   2002-06-18       1
# 2    10243            2662   2002-06-29       0
# 3    10243            2268   2002-07-20       0
# 4    10243            2027   2002-07-31       1

# %%
#创建实体
es = ft.EntitySet(id = 'clients')

#添加clients实体 这个 dataframe 已经有一个索引和一个时间索引
es = es.entity_from_dataframe(entity_id = 'clients', dataframe = clients, 
                              index = 'client_id', time_index = 'joined')

#添加loads实体
es = es.entity_from_dataframe(entity_id = 'loans', dataframe = loans, 
                              variable_types = {'repaid': ft.variable_types.Categorical},
                              index = 'loan_id', 
                              time_index = 'loan_start')


#添加pyments实体
es = es.entity_from_dataframe(entity_id = 'payments', 
                              dataframe = payments,
                              variable_types = {'missed': ft.variable_types.Categorical},
                              make_index = True,
                              index = 'payment_id',
                              time_index = 'payment_date')
#打印实体集
es
# Out:
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 4]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     No relationships

# %%
#添加实体关系
# 通过client_id 关联clients和loans实体
r_client_previous = ft.Relationship(es['clients']['client_id'],
                                    es['loans']['client_id'])
es = es.add_relationship(r_client_previous)

# 通过loan_id 关联payments和loans实体
r_payments = ft.Relationship(es['loans']['loan_id'],
                             es['payments']['loan_id'])
es = es.add_relationship(r_payments)
es
#打印实体集
# es.plot()
# Out:
# 2019-08-30 09:39:19,497 featuretools.entityset - WARNING    Not adding duplicate relationship: <Relationship: loans.client_id -> clients.client_id>
# 2019-08-30 09:39:19,498 featuretools.entityset - WARNING    Not adding duplicate relationship: <Relationship: payments.loan_id -> loans.loan_id>
# Entityset: clients
#   Entities:
#     clients [Rows: 25, Columns: 4]
#     loans [Rows: 443, Columns: 8]
#     payments [Rows: 3456, Columns: 5]
#   Relationships:
#     loans.client_id -> clients.client_id
#     payments.loan_id -> loans.loan_id

# %%
#聚合特征,并生成新特征
features, feature_names = ft.dfs(entityset = es, target_entity = 'clients')
features.head()
# Out:
#            income  credit_score  SUM(loans.loan_amount)  SUM(loans.rate)  \
# client_id
# 25707      211422           621                  159279            69.54
# 26326      227920           633                  116321            40.28
# 26695      174532           680                  140845            44.39
# 26945      214516           806                  106889            42.83
# 29841       38354           523                  176634            62.01
#
#            STD(loans.loan_amount)  STD(loans.rate)  MAX(loans.loan_amount)  \
# client_id
# 25707                 4149.486062         2.484186                   13913
# 26326                 4393.666631         2.057142                   13464
# 26695                 4196.462499         1.561659                   14865
# 26945                 4543.621769         1.619717                   14593
# 29841                 4209.224171         2.122904                   14837
#
#            MAX(loans.rate)  SKEW(loans.loan_amount)  SKEW(loans.rate)  ...  \
# client_id                                                              ...
# 25707                 9.44                -0.186352          0.735470  ...
# 26326                 6.73                 0.149658          1.181651  ...
# 26695                 6.51                 0.168879          0.896574  ...
# 26945                 5.65                 0.174492         -0.002227  ...
# 29841                 6.76                -0.232215          0.055321  ...
#
#            NUM_UNIQUE(loans.WEEKDAY(loan_end))  \
# client_id
# 25707                                        6
# 26326                                        5
# 26695                                        6
# 26945                                        6
# 29841                                        7
#
#            MODE(loans.MODE(payments.missed))  MODE(loans.DAY(loan_start))  \
# client_id
# 25707                                      0                           27
# 26326                                      0                            6
# 26695                                      0                            3
# 26945                                      0                           16
# 29841                                      1                            1
#
#            MODE(loans.DAY(loan_end))  MODE(loans.YEAR(loan_start))  \
# client_id
# 25707                              1                          2010
# 26326                              6                          2003
# 26695                             14                          2003
# 26945                              1                          2002
# 29841                             15                          2005
#
#            MODE(loans.YEAR(loan_end))  MODE(loans.MONTH(loan_start))  \
# client_id
# 25707                            2007                              1
# 26326                            2005                              4
# 26695                            2005                              9
# 26945                            2004                             12
# 29841                            2007                              3
#
#           MODE(loans.MONTH(loan_end))  MODE(loans.WEEKDAY(loan_start))  \
# client_id
# 25707                               8                                3
# 26326                               7                                5
# 26695                               4                                1
# 26945                               5                                0
# 29841                               2                                5
#
#            MODE(loans.WEEKDAY(loan_end))
# client_id
# 25707                                  0
# 26326                                  2
# 26695                                  1
# 26945                                  1
# 29841                                  1
#
# [5 rows x 92 columns]

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(10)
# Out:
#                name         type  \
# 0              skew  aggregation
# 1              mean  aggregation
# 2      percent_true  aggregation
# 3        num_unique  aggregation
# 4             trend  aggregation
# 5              last  aggregation
# 6     n_most_common  aggregation
# 7               max  aggregation
# 8  time_since_first  aggregation
# 9            median  aggregation
#
#                                                                        description
# 0  Computes the extent to which a distribution differs from a normal distribution.
# 1                                       Computes the average for a list of values.
# 2                                         Determines the percent of `True` values.
# 3                 Determines the number of distinct values, ignoring `NaN` values.
# 4                                    Calculates the trend of a variable over time.
# 5                                             Determines the last value in a list.
# 6                                         Determines the `n` most common elements.
# 7                             Calculates the highest value, ignoring `NaN` values.
# 8               Calculates the time elapsed since the first datetime (in seconds).
# 9                            Determines the middlemost number in a list of values.

# %%
primitives[primitives['type'] == 'transform'].head(20)
# Out:
#                                name       type  \
# 20                        not_equal  transform
# 21                            month  transform
# 22            divide_numeric_scalar  transform
# 23                       is_weekend  transform
# 24                     equal_scalar  transform
# 25            modulo_numeric_scalar  transform
# 26                         absolute  transform
# 27                      add_numeric  transform
# 28                            equal  transform
# 29                             hour  transform
# 30                        longitude  transform
# 31            greater_than_equal_to  transform
# 32               less_than_equal_to  transform
# 33                   modulo_numeric  transform
# 34  scalar_subtract_numeric_feature  transform
# 35                          cum_sum  transform
# 36                             diff  transform
# 37              greater_than_scalar  transform
# 38                          weekday  transform
# 39          subtract_numeric_scalar  transform
#
#                                                                     description
# 20              Determines if values in one list are not equal to another list.
# 21                                    Determines the month value of a datetime.
# 22                                 Divide each element in the list by a scalar.
# 23                                     Determines if a date falls on a weekend.
# 24                  Determines if values in a list are equal to a given scalar.
# 25                   Return the modulo of each element in the list by a scalar.
# 26                                     Computes the absolute value of a number.
# 27                                          Element-wise addition of two lists.
# 28                  Determines if values in one list are equal to another list.
# 29                                     Determines the hour value of a datetime.
# 30                  Returns the second tuple value in a list of LatLong tuples.
# 31  Determines if values in one list are greater than or equal to another list.
# 32     Determines if values in one list are less than or equal to another list.
# 33                                            Element-wise modulo of two lists.
# 34                         Subtract each value in the list from a given scalar.
# 35                                               Calculates the cumulative sum.
# 36                   Compute the difference between the value in a list and the
# 37                        Determines if values are greater than a given scalar.
# 38                              Determines the day of the week from a datetime.
# 39                             Subtract a scalar from each element in the list.

# %%
#聚合特征，通过指定聚合agg_primitives和转换trans_primitives生成新特征
features, feature_names = ft.dfs(entityset = es, target_entity = 'clients', 
                                 agg_primitives = ['mean', 'max', 'percent_true', 'last'],
                                 trans_primitives = ['month'])
features.head()
# Out:
#            income  credit_score  MEAN(loans.loan_amount)  MEAN(loans.rate)  \
# client_id
# 25707      211422           621              7963.950000          3.477000
# 26326      227920           633              7270.062500          2.517500
# 26695      174532           680              7824.722222          2.466111
# 26945      214516           806              7125.933333          2.855333
# 29841       38354           523              9813.000000          3.445000
#
#            MAX(loans.loan_amount)  MAX(loans.rate)  LAST(loans.loan_id)  \
# client_id
# 25707                       13913             9.44                10363
# 26326                       13464             6.73                11072
# 26695                       14865             6.51                10985
# 26945                       14593             5.65                11482
# 29841                       14837             6.76                11188
#
#           LAST(loans.loan_type)  LAST(loans.loan_amount)  LAST(loans.rate)  \
# client_id
# 25707                      home                     2203              7.40
# 26326                    credit                     5275              1.45
# 26695                     other                    13918              0.90
# 26945                      cash                     9249              2.86
# 29841                      home                     7223              5.09
#
#                           ...                  \
# client_id                 ...
# 25707                     ...
# 26326                     ...
# 26695                     ...
# 26945                     ...
# 29841                     ...
#
#            MAX(payments.loans.loan_amount)  MAX(payments.loans.rate)  \
# client_id
# 25707                                13913                      9.44
# 26326                                13464                      6.73
# 26695                                14865                      6.51
# 26945                                14593                      5.65
# 29841                                14837                      6.76
#
#            LAST(payments.loans.client_id)  LAST(payments.loans.loan_type)  \
# client_id
# 25707                               25707                            home
# 26326                               26326                          credit
# 26695                               26695                           other
# 26945                               26945                            cash
# 29841                               29841                            home
#
#            LAST(payments.loans.loan_amount)  LAST(payments.loans.rate)  \
# client_id
# 25707                                  2203                       7.40
# 26326                                  5275                       1.45
# 26695                                 13918                       0.90
# 26945                                  9249                       2.86
# 29841                                  7223                       5.09
#
#            LAST(payments.loans.repaid)  MONTH(LAST(loans.loan_start))  \
# client_id
# 25707                                0                              2
# 26326                                0                             11
# 26695                                1                             10
# 26945                                1                             12
# 29841                                1                              6
#
#            MONTH(LAST(loans.loan_end))  MONTH(LAST(payments.payment_date))
# client_id
# 25707                                8                                  11
# 26326                                7                                   8
# 26695                               10                                   3
# 26945                                5                                   7
# 29841                                2                                   1
#
# [5 rows x 38 columns]
